# %%
#library to use dataframes
import pandas as pd

#library to connect & interact with databases
from sqlalchemy import create_engine, inspect


pd.set_option('max_rows',81)

# %%
#set the database file location to a variable
db_file = r'Datasets/boardgames.sqlite'

# set the connection to SQLite database in a variable
engine = create_engine(f"sqlite:///{db_file}")

# %%
#get a list of all the tables in the database
engine.table_names()
# Out:
# ['BoardGames',
#  'bgg.ldaOut.top.documents',
#  'bgg.ldaOut.top.terms',
#  'bgg.ldaOut.topics',
#  'bgg.topics']

# %%
#check if a table exists
engine.has_table('BoardGames')
# Out:
# True

# %%
#this is used to look at the schema of elements in a database
inspector = inspect(engine)

# %%
print(inspector.get_columns('BoardGames'))
# Out:
# [{'name': 'row_names', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'game.id', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'game.type', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.description', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.image', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.maxplayers', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.maxplaytime', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.minage', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.minplayers', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.minplaytime', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.name', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.playingtime', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.thumbnail', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'details.yearpublished', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgameartist', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamecategory', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamecompilation', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamedesigner', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgameexpansion', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamefamily', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgameimplementation', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgameintegration', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamemechanic', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.boardgamepublisher', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'attributes.total', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.average', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.averageweight', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.bayesaverage', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.family.abstracts.bayesaverage', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.family.abstracts.pos', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'stats.family.cgs.bayesaverage', 'type': REAL(), 'nullable': True, 'default': None, 'autoincrement ...

# %%
Boardgame_fields = inspector.get_columns('BoardGames')
Boardgame_field_names = pd.DataFrame.from_dict(Boardgame_fields)
Boardgame_field_names
# Out:
#                                         name     type  nullable default  \
# 0                                  row_names     TEXT      True    None
# 1                                    game.id     TEXT      True    None
# 2                                  game.type     TEXT      True    None
# 3                        details.description     TEXT      True    None
# 4                              details.image     TEXT      True    None
# 5                         details.maxplayers  INTEGER      True    None
# 6                        details.maxplaytime  INTEGER      True    None
# 7                             details.minage  INTEGER      True    None
# 8                         details.minplayers  INTEGER      True    None
# 9                        details.minplaytime  INTEGER      True    None
# 10                              details.name     TEXT      True    None
# 11                       details.playingtime  INTEGER      True    None
# 12                         details.thumbnail     TEXT      True    None
# 13                     details.yearpublished  INTEGER      True    None
# 14                attributes.boardgameartist     TEXT      True    None
# 15              attributes.boardgamecategory     TEXT      True    None
# 16           attributes.boardgamecompilation     TEXT      True    None
# 17              attributes.boardgamedesigner     TEXT      True    None
# 18             attributes.boardgameexpansion     TEXT      True    None
# 19                attributes.boardgamefamily     TEXT      True    None
# 20        attributes.boardgameimplementation     TEXT      True    None
# 21           attributes.boardgameintegration     TEXT      True    None
# 22              attributes.boardgamemechanic     TEXT      True    None
# 23             attributes.boardgamepublisher     TEXT      True    None
# 24                          attributes.total     REAL      True    None
# 25                             stats.average     REAL      True    None
# 26                       stats.averageweight     REAL      True    None
# 27                        stats.bayesaverage     REAL      True    None
# 28       stats.family.abstracts.bayesaverage     REAL      True    None
# 29                stats.family.abstracts.pos     REAL      True    None
# 30             stats.family.cgs.bayesaverage     REAL      True    None
# 31                      stats.family.cgs.pos     REAL      True    None
# 32  stats.family.childrensgames.bayesaverage     REAL      True    None
# 33           stats.family.childrensgames.pos     REAL      True    None
# 34     stats.family.familygames.bayesaverage     REAL      True    None
# 35              stats.family.familygames.pos     REAL      True    None
# 36      stats.family.partygames.bayesaverage     REAL      True    None
# 37               stats.family.partygames.pos     REAL      True    None
# 38   stats.family.strategygames.bayesaverage     REAL      True    None
# 39            stats.family.strategygames.pos     REAL      True    None
# 40        stats.family.thematic.bayesaverage     REAL      True    None
# 41                 stats.family.thematic.pos     REAL      True    None
# 42        stats.family.wargames.bayesaverage     REAL      True    None
# 43                 stats.family.wargames.pos     REAL      True    None
# 44                              stats.median     REAL      True    None
# 45                         stats.numcomments     REAL      True    None
# 46                          stats.numweights     REAL      True    None
# 47                               stats.owned     REAL      True    None
# 48                              stats.stddev     REAL      True    None
# 49      stats.subtype.boardgame.bayesaverage     REAL      True    None
# 50               stats.subtype.boardgame.pos     REAL      True    None
# 51                             stats.trading     REAL      True    None
# 52                          stats.usersrated     REAL      True    None
# 53                             stats.wanting     REAL      True    None
# 54                             stats.wishing     REAL      True    None
# 55                 polls.language_dependence     TEXT      True    None
# 56              polls.suggested_numplayers.1     TEXT      True    None
# 57             polls.suggested_numplayers.10     TEXT      True    None
# 58              polls.suggested_numplayers.2     TEXT      True    None
# 59              polls.suggested_numplayers.3     TEXT      True    None
# 60              polls.suggested_numplayers.4     TEXT      True    None
# 61              polls.suggested_numplayers.5     TEXT      True    None
# 62              polls.suggested_numplayers.6     TEXT      True    None
# 63              polls.suggested_numplayers.7     TEXT      True    None
# 64              polls.suggested_numplayers.8     TEXT      True    None
# 65              polls.suggested_numplayers.9     TEXT      True    None
# 66           polls.suggested_numplayers.Over     TEXT      True    None
# 67                 polls.suggested_playerage     TEXT      True    None
# 68           attributes.t.links.concat.2....     TEXT      True    None
# 69           stats.family.amiga.bayesaverage     REAL      True    None
# 70                    stats.family.amiga.pos     REAL      True    None
# 71          stats.family.arcade.bayesaverage     REAL      True    None
# 72                   stats.family.arcade.pos     REAL      True    None
# 73         stats.family.atarist.bayesaverage     REAL      True    None
# 74                  stats.family.atarist.pos     REAL      True    None
# 75     stats.family.commodore64.bayesaverage     REAL      True    None
# 76              stats.family.commodore64.pos     REAL      True    None
# 77        stats.subtype.rpgitem.bayesaverage     REAL      True    None
# 78                 stats.subtype.rpgitem.pos     REAL      True    None
# 79      stats.subtype.videogame.bayesaverage     REAL      True    None
# 80               stats.subtype.videogame.pos     REAL      True    None
#
#    autoincrement  primary_key
# 0           auto            0
# 1           auto            0
# 2           auto            0
# 3           auto            0
# 4           auto            0
# 5           auto            0
# 6           auto            0
# 7           auto            0
# 8           auto            0
# 9           auto            0
# 10          auto            0
# 11          auto            0
# 12          auto            0
# 13          auto            0
# 14          auto            0
# 15          auto            0
# 16          auto            0
# 17          auto            0
# 18          auto            0
# 19          auto            0
# 20          auto            0
# 21          auto            0
# 22          auto            0
# 23          auto            0
# 24          auto            0
# 25          auto            0
# 26          auto            0
# 27          auto            0
# 28          auto            0
# 29          auto            0
# 30          auto            0
# 31          auto            0
# 32          auto            0
# 33          auto            0
# 34          auto            0
# 35          auto            0
# 36          auto            0
# 37          auto            0
# 38          auto            0
# 39          auto            0
# 40          auto            0
# 41          auto            0
# 42          auto            0
# 43          auto            0
# 44          auto            0
# 45          auto            0
# 46          auto            0
# 47          auto            0
# 48          auto            0
# 49          auto            0
# 50          auto            0
# 51          auto            0
# 52          auto            0
# 53          auto            0
# 54          auto            0
# 55          auto            0
# 56          auto            0
# 57          auto            0
# 58          auto            0
# 59          auto            0
# 60          auto            0
# 61          auto            0
# 62          auto            0
# 63          auto            0
# 64          auto            0
# 65          auto            0
# 66          auto            0
# 67          auto            0
# 68          auto            0
# 69          auto            0
# 70          auto            0
# 71          auto            0
# 72          auto            0
# 73          auto            0
# 74          auto            0
# 75          auto            0
# 76          auto            0
# 77          auto            0
# 78          auto            0
# 79          auto            0
# 80          auto            0

# %% [markdown]
# documents_fields = inspector.get_columns('bgg.ldaOut.top.documents')
# documents_field_names = pd.DataFrame.from_dict(documents_fields)
# print(documents_field_names)

# %%
documents_fields = inspector.get_columns('bgg.ldaOut.top.documents')
documents_field_names = pd.DataFrame.from_dict(documents_fields)
documents_field_names
# Out:
#         name     type  nullable default autoincrement  primary_key
# 0  row_names     TEXT      True    None          auto            0
# 1   document     TEXT      True    None          auto            0
# 2      topic  INTEGER      True    None          auto            0
# 3      gamma     REAL      True    None          auto            0

# %%
#get all the rows from the "test" table in the database
sql = "SELECT * FROM BoardGames;"

#the read_sql function takes in the SQL statement for the information requested and the engine (to connect to database)
boardgames_df = pd.read_sql(sql, engine)
len(boardgames_df.index)
# Out:
# 90400

# %%
boardgames_df.shape
# Out:
# (90400, 81)

# %%
terms_fields = inspector.get_columns('bgg.ldaOut.top.terms')
terms_field_names = pd.DataFrame.from_dict(terms_fields)
terms_field_names
# Out:
#         name     type  nullable default autoincrement  primary_key
# 0  row_names     TEXT      True    None          auto            0
# 1      topic  INTEGER      True    None          auto            0
# 2       term     TEXT      True    None          auto            0
# 3       beta     REAL      True    None          auto            0

# %%
#get all the rows from the "test" table in the database
sql = "SELECT * FROM 'bgg.ldaOut.top.documents';"

#the read_sql function takes in the SQL statement for the information requested and the engine (to connect to database)
docs_df = pd.read_sql(sql, engine)
docs_df.shape
# Out:
# (288, 4)

# %%
#get all the rows from the "test" table in the database
sql = "SELECT * FROM 'bgg.ldaOut.top.terms';"

#the read_sql function takes in the SQL statement for the information requested and the engine (to connect to database)
terms_df = pd.read_sql(sql, engine)
terms_df.shape
# Out:
# (250, 4)

# %%
topics_fields = inspector.get_columns('bgg.ldaOut.topics')
topics_field_names = pd.DataFrame.from_dict(topics_fields)
topics_field_names
# Out:
#                  name     type  nullable default autoincrement  primary_key
# 0           row_names     TEXT      True    None          auto            0
# 1  topics(bgg.ldaOut)  INTEGER      True    None          auto            0

# %%
#get all the rows from the "test" table in the database
sql = "SELECT * FROM 'bgg.ldaOut.topics';"

#the read_sql function takes in the SQL statement for the information requested and the engine (to connect to database)
topics_df = pd.read_sql(sql, engine)
topics_df.shape
# Out:
# (29229, 2)

# %%
justtopics_fields = inspector.get_columns('bgg.topics')
justtopics_field_names = pd.DataFrame.from_dict(justtopics_fields)
justtopics_field_names
# Out:
#                                         name     type  nullable default  \
# 0                                  row_names     TEXT      True    None
# 1                                    game.id     TEXT      True    None
# 2                                  game.type     TEXT      True    None
# 3                         details.maxplayers  INTEGER      True    None
# 4                        details.maxplaytime  INTEGER      True    None
# 5                             details.minage  INTEGER      True    None
# 6                         details.minplayers  INTEGER      True    None
# 7                        details.minplaytime  INTEGER      True    None
# 8                               details.name     TEXT      True    None
# 9                        details.playingtime     REAL      True    None
# 10                     details.yearpublished  INTEGER      True    None
# 11                attributes.boardgameartist     TEXT      True    None
# 12              attributes.boardgamecategory     TEXT      True    None
# 13           attributes.boardgamecompilation     TEXT      True    None
# 14              attributes.boardgamedesigner     TEXT      True    None
# 15             attributes.boardgameexpansion     TEXT      True    None
# 16                attributes.boardgamefamily     TEXT      True    None
# 17        attributes.boardgameimplementation     TEXT      True    None
# 18           attributes.boardgameintegration     TEXT      True    None
# 19              attributes.boardgamemechanic     TEXT      True    None
# 20             attributes.boardgamepublisher     TEXT      True    None
# 21                          attributes.total     REAL      True    None
# 22                             stats.average     REAL      True    None
# 23                       stats.averageweight     REAL      True    None
# 24                        stats.bayesaverage     REAL      True    None
# 25       stats.family.abstracts.bayesaverage     REAL      True    None
# 26                stats.family.abstracts.pos     REAL      True    None
# 27             stats.family.cgs.bayesaverage     REAL      True    None
# 28                      stats.family.cgs.pos     REAL      True    None
# 29  stats.family.childrensgames.bayesaverage     REAL      True    None
# 30           stats.family.childrensgames.pos     REAL      True    None
# 31     stats.family.familygames.bayesaverage     REAL      True    None
# 32              stats.family.familygames.pos     REAL      True    None
# 33      stats.family.partygames.bayesaverage     REAL      True    None
# 34               stats.family.partygames.pos     REAL      True    None
# 35   stats.family.strategygames.bayesaverage     REAL      True    None
# 36            stats.family.strategygames.pos     REAL      True    None
# 37        stats.family.thematic.bayesaverage     REAL      True    None
# 38                 stats.family.thematic.pos     REAL      True    None
# 39        stats.family.wargames.bayesaverage     REAL      True    None
# 40                 stats.family.wargames.pos     REAL      True    None
# 41                         stats.numcomments     REAL      True    None
# 42                          stats.numweights     REAL      True    None
# 43                               stats.owned     REAL      True    None
# 44                              stats.stddev     REAL      True    None
# 45      stats.subtype.boardgame.bayesaverage     REAL      True    None
# 46               stats.subtype.boardgame.pos     REAL      True    None
# 47                             stats.trading     REAL      True    None
# 48                          stats.usersrated     REAL      True    None
# 49                             stats.wanting     REAL      True    None
# 50                             stats.wishing     REAL      True    None
# 51                 polls.language_dependence     TEXT      True    None
# 52              polls.suggested_numplayers.1     TEXT      True    None
# 53             polls.suggested_numplayers.10     TEXT      True    None
# 54              polls.suggested_numplayers.2     TEXT      True    None
# 55              polls.suggested_numplayers.3     TEXT      True    None
# 56              polls.suggested_numplayers.4     TEXT      True    None
# 57              polls.suggested_numplayers.5     TEXT      True    None
# 58              polls.suggested_numplayers.6     TEXT      True    None
# 59              polls.suggested_numplayers.7     TEXT      True    None
# 60              polls.suggested_numplayers.8     TEXT      True    None
# 61              polls.suggested_numplayers.9     TEXT      True    None
# 62           polls.suggested_numplayers.Over     TEXT      True    None
# 63                 polls.suggested_playerage     TEXT      True    None
# 64           attributes.t.links.concat.2....     TEXT      True    None
# 65        stats.subtype.rpgitem.bayesaverage     REAL      True    None
# 66                 stats.subtype.rpgitem.pos     REAL      True    None
# 67                       stats.weight.factor     TEXT      True    None
# 68                details.playingtime.factor     TEXT      True    None
# 69                 details.minplayers.factor     TEXT      True    None
# 70                 details.maxplayers.factor     TEXT      True    None
# 71                     details.minage.factor     TEXT      True    None
# 72                      stats.average.factor     TEXT      True    None
# 73                                     topic     TEXT      True    None
#
#    autoincrement  primary_key
# 0           auto            0
# 1           auto            0
# 2           auto            0
# 3           auto            0
# 4           auto            0
# 5           auto            0
# 6           auto            0
# 7           auto            0
# 8           auto            0
# 9           auto            0
# 10          auto            0
# 11          auto            0
# 12          auto            0
# 13          auto            0
# 14          auto            0
# 15          auto            0
# 16          auto            0
# 17          auto            0
# 18          auto            0
# 19          auto            0
# 20          auto            0
# 21          auto            0
# 22          auto            0
# 23          auto            0
# 24          auto            0
# 25          auto            0
# 26          auto            0
# 27          auto            0
# 28          auto            0
# 29          auto            0
# 30          auto            0
# 31          auto            0
# 32          auto            0
# 33          auto            0
# 34          auto            0
# 35          auto            0
# 36          auto            0
# 37          auto            0
# 38          auto            0
# 39          auto            0
# 40          auto            0
# 41          auto            0
# 42          auto            0
# 43          auto            0
# 44          auto            0
# 45          auto            0
# 46          auto            0
# 47          auto            0
# 48          auto            0
# 49          auto            0
# 50          auto            0
# 51          auto            0
# 52          auto            0
# 53          auto            0
# 54          auto            0
# 55          auto            0
# 56          auto            0
# 57          auto            0
# 58          auto            0
# 59          auto            0
# 60          auto            0
# 61          auto            0
# 62          auto            0
# 63          auto            0
# 64          auto            0
# 65          auto            0
# 66          auto            0
# 67          auto            0
# 68          auto            0
# 69          auto            0
# 70          auto            0
# 71          auto            0
# 72          auto            0
# 73          auto            0

# %%
#get all the rows from the "test" table in the database
sql = "SELECT * FROM 'bgg.topics';"

#the read_sql function takes in the SQL statement for the information requested and the engine (to connect to database)
justtopics_df = pd.read_sql(sql, engine)
justtopics_df.shape
# Out:
# (29313, 74)
